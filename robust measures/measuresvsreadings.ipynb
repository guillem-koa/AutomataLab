# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/guillemcobos/Library/CloudStorage/GoogleDrive-guillem.cobos@koabiotech.com/.shortcut-targets-by-id/1UQ_YnLRmoAqhCue-qXYNP9QhYorsiAxS/KOA Biotech/01. AUTOMATA LAB/GLOBAL OUTPUTS/combined_global.xlsx")

# %%
measure_abs = df.iloc[:,9:20].values.flatten()
measure_gfp = df.iloc[:,20:31].values.flatten()
reading_abs = df.iloc[:,31:42].values.flatten()
reading_gfp = df.iloc[:,42:53].values.flatten()

# %%
comparison_df = pd.DataFrame({'measure_abs': measure_abs, 
                            'reading_abs': reading_abs, 
                            'measure_gfp': measure_gfp, 
                            'reading_gfp': reading_gfp})

# %%
comparison_df
# Out:
#       measure_abs  reading_abs  measure_gfp  reading_gfp
# 0           179.0       0.6635         50.0     51415464
# 1           175.0       0.6624         47.0     38621248
# 2           175.0       0.9744         45.0     26282512
# 3           172.0       1.1400         45.0     20126438
# 4           172.0       0.9866         44.0     31514662
# ...           ...          ...          ...          ...
# 4659          NaN       0.5323          NaN     27178504
# 4660          NaN       0.6412          NaN     29148716
# 4661          NaN       0.7128          NaN     26035558
# 4662          NaN       0.7895          NaN     25756830
# 4663          NaN       0.0928          NaN     27304418
#
# [4664 rows x 4 columns]

# %%
sns.scatterplot(x = 'reading_gfp', y = 'measure_gfp', data=comparison_df)
# Out:
# <Axes: xlabel='reading_gfp', ylabel='measure_gfp'>
